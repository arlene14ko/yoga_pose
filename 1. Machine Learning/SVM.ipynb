# %%
import tensorflow as tf

import cv2
import os

import numpy as np

# %%
import pandas as pd
df = pd.read_csv('dataset.csv')

# %%
len(df)
# Out:
# 513

# %%
df.head()
# Out:
#                                         class        x0        y0        z0  \
# 0  Adho mukha svanasana - Downward-facing Dog  0.490031  0.759308 -0.057471
# 1  Adho mukha svanasana - Downward-facing Dog  0.485790  0.760255 -0.029428
# 2  Adho mukha svanasana - Downward-facing Dog  0.481833  0.749507 -0.061982
# 3  Adho mukha svanasana - Downward-facing Dog  0.491385  0.745805 -0.039555
# 4  Adho mukha svanasana - Downward-facing Dog  0.468007  0.755088 -0.107148
#
#          v0        x1        y1        z1        v1        x2  ...       z30  \
# 0  0.999915  0.500056  0.755584 -0.047095  0.999920  0.500699  ...  0.052691
# 1  0.999592  0.496677  0.760252 -0.017626  0.999563  0.497819  ...  0.055273
# 2  0.999264  0.493204  0.754042 -0.052008  0.999340  0.494498  ... -0.018221
# 3  0.999747  0.501969  0.748230 -0.028987  0.999742  0.503439  ...  0.025266
# 4  0.999898  0.479416  0.760685 -0.094679  0.999896  0.480828  ...  0.062055
#
#         v30       x31       y31       z31       v31       x32       y32  \
# 0  0.996797  0.279771  0.833945  0.243554  0.910503  0.270018  0.856671
# 1  0.995301  0.287544  0.827749  0.228765  0.854848  0.276033  0.847152
# 2  0.998571  0.309814  0.819004  0.178746  0.939306  0.284677  0.841712
# 3  0.997481  0.321623  0.834647  0.203519  0.905652  0.311496  0.856482
# 4  0.997080  0.322556  0.829728  0.251807  0.924806  0.307081  0.849876
#
#         z32       v32
# 0 -0.025365  0.998438
# 1 -0.026866  0.997748
# 2 -0.099234  0.999354
# 3 -0.055656  0.998913
# 4 -0.026802  0.998917
#
# [5 rows x 133 columns]

# %%
from sklearn.preprocessing import LabelEncoder

LE = LabelEncoder()
df['target'] = LE.fit_transform(df['class'])

# %%
df
# Out:
#                                           class        x0        y0        z0  \
# 0    Adho mukha svanasana - Downward-facing Dog  0.490031  0.759308 -0.057471
# 1    Adho mukha svanasana - Downward-facing Dog  0.485790  0.760255 -0.029428
# 2    Adho mukha svanasana - Downward-facing Dog  0.481833  0.749507 -0.061982
# 3    Adho mukha svanasana - Downward-facing Dog  0.491385  0.745805 -0.039555
# 4    Adho mukha svanasana - Downward-facing Dog  0.468007  0.755088 -0.107148
# ..                                          ...       ...       ...       ...
# 508          Uttanasana - Standing Forward Bend  0.563940  0.709303 -0.015861
# 509          Uttanasana - Standing Forward Bend  0.579806  0.715018  0.004251
# 510          Uttanasana - Standing Forward Bend  0.579068  0.711553 -0.043414
# 511          Uttanasana - Standing Forward Bend  0.577557  0.711253 -0.013271
# 512          Uttanasana - Standing Forward Bend  0.582584  0.696587 -0.002388
#
#            v0        x1        y1        z1        v1        x2  ...  \
# 0    0.999915  0.500056  0.755584 -0.047095  0.999920  0.500699  ...
# 1    0.999592  0.496677  0.760252 -0.017626  0.999563  0.497819  ...
# 2    0.999264  0.493204  0.754042 -0.052008  0.999340  0.494498  ...
# 3    0.999747  0.501969  0.748230 -0.028987  0.999742  0.503439  ...
# 4    0.999898  0.479416  0.760685 -0.094679  0.999896  0.480828  ...
# ..        ...       ...       ...       ...       ...       ...  ...
# 508  0.999877  0.572540  0.718796 -0.006796  0.999551  0.574079  ...
# 509  0.999988  0.592302  0.714799  0.015915  0.999966  0.593242  ...
# 510  0.999859  0.590177  0.710548 -0.031884  0.999576  0.591256  ...
# 511  0.999894  0.589083  0.709289 -0.002676  0.999828  0.589928  ...
# 512  0.999941  0.593389  0.691628  0.008322  0.999923  0.593970  ...
#
#           v30       x31       y31       z31       v31       x32       y32  \
# 0    0.996797  0.279771  0.833945  0.243554  0.910503  0.270018  0.856671
# 1    0.995301  0.287544  0.827749  0.228765  0.854848  0.276033  0.847152
# 2    0.998571  0.309814  0.819004  0.178746  0.939306  0.284677  0.841712
# 3    0.997481  0.321623  0.834647  0.203519  0.905652  0.311496  0.856482
# 4    0.997080  0.322556  0.829728  0.251807  0.924806  0.307081  0.849876
# ..        ...       ...       ...       ...       ...       ...       ...
# 508  0.925738  0.539025  0.864815  0.226189  0.443449  0.541203  0.869124
# 509  0.955579  0.540875  0.861356  0.192298  0.617509  0.542630  0.872515
# 510  0.851145  0.542995  0.853005  0.161182  0.257018  0.543919  0.863454
# 511  0.923972  0.544783  0.851775  0.110742  0.431823  0.542060  0.862494
# 512  0.941124  0.546550  0.859041  0.104649  0.454290  0.544075  0.871115
#
#           z32       v32  target
# 0   -0.025365  0.998438       0
# 1   -0.026866  0.997748       0
# 2   -0.099234  0.999354       0
# 3   -0.055656  0.998913       0
# 4   -0.026802  0.998917       0
# ..        ...       ...     ...
# 508  0.025284  0.947647      11
# 509 -0.026698  0.981065      11
# 510 -0.031308  0.904901      11
# 511 -0.068584  0.951600      11
# 512 -0.083375  0.962701      11
#
# [513 rows x 134 columns]

# %%
df.columns
# Out:
# Index(['Pose', 'Path', 'image', 'left_shoulder_x', 'left_shoulder_y',
#        'right_shoulder_x', 'right_shoulder_y', 'left_elbow_x', 'left_elbow_y',
#        'right_elbow_x', 'right_elbow_y', 'left_wrist_x', 'left_wrist_y',
#        'right_wrist_x', 'right_wrist_y', 'left_hip_x', 'left_hip_y',
#        'right_hip_x', 'right_hip_y', 'left_knee_x', 'left_knee_y',
#        'right_knee_x', 'right_knee_y', 'left_ankle_x', 'left_ankle_y',
#        'right_ankle_x', 'right_ankle_y'],
#       dtype='object')

# %%
y = df['target']
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 508    11
# 509    11
# 510    11
# 511    11
# 512    11
# Name: target, Length: 513, dtype: int64

# %%
df = df.drop('target', 1)

# %%
X = df.iloc[:, 1:]

# %%
X
# Out:
#            x0        y0        z0        v0        x1        y1        z1  \
# 0    0.490031  0.759308 -0.057471  0.999915  0.500056  0.755584 -0.047095
# 1    0.485790  0.760255 -0.029428  0.999592  0.496677  0.760252 -0.017626
# 2    0.481833  0.749507 -0.061982  0.999264  0.493204  0.754042 -0.052008
# 3    0.491385  0.745805 -0.039555  0.999747  0.501969  0.748230 -0.028987
# 4    0.468007  0.755088 -0.107148  0.999898  0.479416  0.760685 -0.094679
# ..        ...       ...       ...       ...       ...       ...       ...
# 508  0.563940  0.709303 -0.015861  0.999877  0.572540  0.718796 -0.006796
# 509  0.579806  0.715018  0.004251  0.999988  0.592302  0.714799  0.015915
# 510  0.579068  0.711553 -0.043414  0.999859  0.590177  0.710548 -0.031884
# 511  0.577557  0.711253 -0.013271  0.999894  0.589083  0.709289 -0.002676
# 512  0.582584  0.696587 -0.002388  0.999941  0.593389  0.691628  0.008322
#
#            v1        x2        y2  ...       z30       v30       x31  \
# 0    0.999920  0.500699  0.752798  ...  0.052691  0.996797  0.279771
# 1    0.999563  0.497819  0.757827  ...  0.055273  0.995301  0.287544
# 2    0.999340  0.494498  0.752223  ... -0.018221  0.998571  0.309814
# 3    0.999742  0.503439  0.746292  ...  0.025266  0.997481  0.321623
# 4    0.999896  0.480828  0.759402  ...  0.062055  0.997080  0.322556
# ..        ...       ...       ...  ...       ...       ...       ...
# 508  0.999551  0.574079  0.716787  ...  0.091428  0.925738  0.539025
# 509  0.999966  0.593242  0.712770  ...  0.043072  0.955579  0.540875
# 510  0.999576  0.591256  0.708763  ...  0.051361  0.851145  0.542995
# 511  0.999828  0.589928  0.706900  ...  0.010511  0.923972  0.544783
# 512  0.999923  0.593970  0.689258  ... -0.004535  0.941124  0.546550
#
#           y31       z31       v31       x32       y32       z32       v32
# 0    0.833945  0.243554  0.910503  0.270018  0.856671 -0.025365  0.998438
# 1    0.827749  0.228765  0.854848  0.276033  0.847152 -0.026866  0.997748
# 2    0.819004  0.178746  0.939306  0.284677  0.841712 -0.099234  0.999354
# 3    0.834647  0.203519  0.905652  0.311496  0.856482 -0.055656  0.998913
# 4    0.829728  0.251807  0.924806  0.307081  0.849876 -0.026802  0.998917
# ..        ...       ...       ...       ...       ...       ...       ...
# 508  0.864815  0.226189  0.443449  0.541203  0.869124  0.025284  0.947647
# 509  0.861356  0.192298  0.617509  0.542630  0.872515 -0.026698  0.981065
# 510  0.853005  0.161182  0.257018  0.543919  0.863454 -0.031308  0.904901
# 511  0.851775  0.110742  0.431823  0.542060  0.862494 -0.068584  0.951600
# 512  0.859041  0.104649  0.454290  0.544075  0.871115 -0.083375  0.962701
#
# [513 rows x 132 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
# SVM

linear = svm.SVC(kernel='linear', C=1, decision_function_shape='ovo').fit(X_train, y_train)
rbf = svm.SVC(kernel='rbf', gamma=1, C=1, decision_function_shape='ovo').fit(X_train, y_train)
poly = svm.SVC(kernel='poly', degree=3, C=1, decision_function_shape='ovo').fit(X_train, y_train)
sig = svm.SVC(kernel='sigmoid', C=1, decision_function_shape='ovo').fit(X_train, y_train)

# %%
from sklearn.metrics import classification_report

print("linear")
linear_pred = linear.predict(X_test)
print(classification_report(y_test,linear_pred))


print("rbf")
poly_pred = poly.predict(X_test)
print(classification_report(y_test,poly_pred))


print("poly")
rbf_pred = rbf.predict(X_test)
print(classification_report(y_test,rbf_pred))
# Out:
# linear
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         8
#            1       1.00      1.00      1.00         2
#            2       1.00      1.00      1.00        21
#            3       1.00      1.00      1.00        18
#            4       1.00      1.00      1.00         5
#            5       1.00      1.00      1.00         3
#            6       1.00      1.00      1.00         1
#            7       1.00      1.00      1.00         1
#            8       1.00      1.00      1.00         6
#            9       1.00      1.00      1.00        26
#           10       1.00      1.00      1.00         4
#           11       1.00      1.00      1.00         8
#
#     accuracy                           1.00       103
#    macro avg       1.00      1.00      1.00       103
# weighted avg       1.00      1.00      1.00       103
#
# rbf
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         8
#            1       1.00      1.00      1.00         2
#            2       1.00      1.00      1.00        21
#            3       1.00      1.00      1.00        18
#            4       1.00      1.00      1.00         5
#            5       1.00      1.00      1.00         3
#            6       1.00      1.00      1.00         1
#            7       1.00      1.00      1.00         1
#            8       1.00      1.00      1.00         6
#            9       1.00      1.00      1.00        26
#           10       1.00      1.00      1.00         4
#           11       1.00      1.00      1.00         8
#
#     accuracy                           1.00       103
#    macro avg       1.00      1.00      1.00       103
# weighted avg       1.00      1.00      1.00       103
#
# poly
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         8
#            1       1.00      1.00      1.00         2
#            2       1.00      1.00      1.00        21
#            3       1.00      1.00      1.00        18
#            4       1.00      1.00      1.00         5
#            5       1.00      1.00      1.00         3
#            6       1.00      1.00      1.00         1
#            7       1.00      1.00      1.00         1
#            8       1.00      1.00      1.00         6
#            9       1.00      1.00      1.00        26
#           10       1.00      1.00      1.00         4
#           11       1.00      1.00      1.00         8
#
#     accuracy                           1.00       103
#    macro avg       1.00      1.00      1.00       103
# weighted avg       1.00      1.00      1.00       103
#
# sigmoid
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         8
#            1       0.00      0.00      0.00         2
#            2       0.00      0.00      0.00        21
#            3       0.00      0.00      0.00        18
#            4       0.00      0.00      0.00         5
#            5       0.00      0.00      0.00         3
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         1
#            8       0.00      0.00      0.00         6
#            9       0.25      1.00      0.40        26
#           10       0.00      0.00      0.00         4
#           11       0.00      0.00      0.00         8
#
#     accuracy                           0.25       103
#    macro avg       0.02      0.08      0.03       103
# weighted avg       0.06      0.25      0.10       103
# /home/ms/anaconda3/envs/computer_vision/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ms/anaconda3/envs/computer_vision/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ms/anaconda3/envs/computer_vision/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import pickle
with open("yoga_poses_model.pkl", 'wb') as f:
    pickle.dump(rbf, f)

# %%
with open("yoga_poses_model.pkl", 'rb') as f:
    rbf_model = pickle.load(f)

# %%
y_pred = rbf_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         8
#            1       1.00      1.00      1.00         2
#            2       1.00      1.00      1.00        21
#            3       1.00      1.00      1.00        18
#            4       1.00      1.00      1.00         5
#            5       1.00      1.00      1.00         3
#            6       1.00      1.00      1.00         1
#            7       1.00      1.00      1.00         1
#            8       1.00      1.00      1.00         6
#            9       1.00      1.00      1.00        26
#           10       1.00      1.00      1.00         4
#           11       1.00      1.00      1.00         8
#
#     accuracy                           1.00       103
#    macro avg       1.00      1.00      1.00       103
# weighted avg       1.00      1.00      1.00       103
